# %%
import os
import time
import psutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from threading import Thread, Event

# %%
class MemoryMonitor(Thread):

    def __init__(self, interval):
        Thread.__init__(self)
        self.daemon = True
        self.interval = interval
        self.process = psutil.Process(os.getpid())
        self.buffer = []
        self.stopped = Event()

    def monitor(self):
        self.buffer.append((time.time(), self.process.memory_info().rss))
        
    def run(self):
        while not self.stopped.wait(self.interval):
            self.monitor()

    def stop(self):
        self.stopped.set()

# %%
GB = 1024**3/8
SIZE = int(1.0*GB)

# %%
def malloc():
    data = np.ones(SIZE)
    df = pd.DataFrame()
    df['MyCol'] = data
    return df

monitor = MemoryMonitor(0.01)
monitor.start()
df = malloc()
monitor.stop()
time.sleep(1)

arr = np.array(monitor.buffer)
plt.plot(arr[:, 0], arr[:, 1])
plt.title('Peak={}\nElapsed={}'.format(np.max(arr[:, 1]), arr[:, 0][-1]-arr[:, 0][0]))
# Out:
# Text(0.5, 1.0, 'Peak=7696535552.0\nElapsed=8.281633853912354')

# %%
def malloc():
    data = np.ones(SIZE)
    df = pd.DataFrame(data=data, columns=['MyCol'])
    return df

monitor = MemoryMonitor(0.01)
monitor.start()
malloc()
monitor.stop()
time.sleep(1)

arr = np.array(monitor.buffer)
plt.plot(arr[:, 0], arr[:, 1])
plt.title('Peak={}\nElapsed={}'.format(np.max(arr[:, 1]), arr[:, 0][-1]-arr[:, 0][0]))
# Out:
# Text(0.5, 1.0, 'Peak=3264413696.0\nElapsed=0.15739035606384277')

# %%
def malloc():
    data = [float(1.0)]*SIZE
    df = pd.DataFrame(data=data, columns=['MyCol'])
    return df

monitor = MemoryMonitor(0.01)
monitor.start()
df = malloc()
monitor.stop()
time.sleep(1)

arr = np.array(monitor.buffer)
plt.plot(arr[:, 0], arr[:, 1])
plt.title('Peak={}\nElapsed={}'.format(np.max(arr[:, 1]), arr[:, 0][-1]-arr[:, 0][0]))
# Out:
# Text(0.5, 1.0, 'Peak=4413018112.0\nElapsed=10.742066383361816')

# %%
def malloc():
    data = [float(1.0)]*SIZE
    data = np.array(data)
    df = pd.DataFrame(data=data, columns=['MyCol'])
    return df

monitor = MemoryMonitor(0.01)
monitor.start()
df = malloc()
monitor.stop()
time.sleep(1)

arr = np.array(monitor.buffer)
plt.plot(arr[:, 0], arr[:, 1])
plt.title('Peak={}\nElapsed={}'.format(np.max(arr[:, 1]), arr[:, 0][-1]-arr[:, 0][0]))
# Out:
# Text(0.5, 1.0, 'Peak=3340464128.0\nElapsed=4.766741991043091')

# %%
def malloc():
    data = np.empty(SIZE)
    data[:] = [float(1.0)]*SIZE
    df = pd.DataFrame(data=data, columns=['MyCol'])
    return df

monitor = MemoryMonitor(0.01)
monitor.start()
df = malloc()
monitor.stop()
time.sleep(1)

arr = np.array(monitor.buffer)
plt.plot(arr[:, 0], arr[:, 1])
plt.title('Peak={}\nElapsed={}'.format(np.max(arr[:, 1]), arr[:, 0][-1]-arr[:, 0][0]))
# Out:
# Text(0.5, 1.0, 'Peak=1194123264.0\nElapsed=0.0')
